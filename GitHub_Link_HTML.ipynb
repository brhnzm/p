# %%
link = input(" ")
 
a = link.find(".com/")+5
b = link.find("/",19)
c = link.find("blob")
d = link[(link.find("/",19)):(link.find("blob"))]
e = link.find("main/")+5
f = link[e:]

# %%
print ("https://"+link[a:b]+".github.io"+d+f)
