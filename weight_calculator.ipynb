# %% [markdown]
# # Welcome to Jupyter!

# %%
weight = float (input ('Weight: '))
unit = input ('(L)bs or (K)g: ')
if unit.upper() == 'L':
    result = weight*0.45359237
    print (f"{result} kg")
else:
    result= weight/0.45359237
    print (f"{result} lbs")
