# %%
 
#@markdown <h2><b>←</b> ឵឵Click Here to run the code. </h2>
#@markdown <h5><i>(Coded by Muhammad Borhan Uddin Nezami)</i></h5>
 
 
x = input('Input text1: ')
y = input('Input text2: ')
exact = x == y
match_ignoring_case = x.lower() == y.lower()
if exact:
   print("Exact match")
elif match_ignoring_case:
        print ('Match but not in case.')
else:
   print('Do not match')

# %%
#@title
 # Case sensitive
x = 'Borhan'
y = 'borhan'
z = x == y
print (z)

# %%
#@title
 # Not case sensitive using .lower()
 
x = 'Borhan'
y = 'borhan'
z = x.lower() == y.lower()
print (z)

# %%
#@title
# Not case sensitive using .upper()
 
x = 'Borhan'
y = 'borhan'
z = x.upper() == y.upper()
print (z)
