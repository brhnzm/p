# %%
from datetime import date
from datetime import datetime
import pytz
date = date.today().strftime("%Y%m%d")
tz_bd = pytz.timezone('Asia/Dhaka')
datetime_bd = datetime.now(tz_bd)
time = datetime_bd.strftime("%H%M%S")
print (date+time)
