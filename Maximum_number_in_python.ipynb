# %%
 
#@markdown <h3> Get the maximum number from a list of numbers.
numbers = [15, 9, 5, 2, 8, 7, 19]
max_num = numbers[0]
for number in numbers:
    if number > max_num:
        max_num = number
print(max_num)
